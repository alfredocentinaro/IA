# %%
# !nvidia-smi
# Out:
# Sat May  4 07:40:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8              13W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (16 CPUs, 62.8 GB RAM, 28.8/78.2 GB disk)

# %%
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.2/755.2 kB 4.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
# @title Testo del titolo predefinito
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !scp '/content/gdrive/MyDrive/yolov8/nail.v3i.yolov8.zip' '/content/'

# %%
# !unzip '/content/nail.v3i.yolov8.zip'  -d '/content/'
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.787b7a3ee8d91cf031c7e8683ae5be0a.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.8c79afa99221a047afc0a086c1fe0952.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.950e9f57e22c582befe8f90628b8202e.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.cb647674b245500de4026b64a305bbcb.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.cebdac65d68ec3dfcf238e5a902f1dfb.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.cf6c3d7086bb98779201e9bcaa183563.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.d345bbb69fe62441d6878750bad25f41.txt
#  extracting: /content/train/labels/WIN_20221004_16_21_46_Pro_jpg.rf.dd63bd1024b0e9aad94612af61316e3d.txt
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=80 imgsz=640 plots=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 73.5MB/s]
# Ultralytics YOLOv8.2.8 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !zip -r /content/runs_yolov8bis.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/R_curve.png (deflated 21%)
#   adding: content/runs/detect/train/train_batch63562.jpg (deflated 17%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 29%)
#   adding: content/runs/detect/train/train_batch63560.jpg (deflated 10%)
#   adding: content/runs/detect/train/results.png (deflated 9%)
#   adding: content/runs/detect/train/train_batch63561.jpg (deflated 14%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 40%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 17%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 31%)
#   adding: content/runs/detect/train/P_curve.png (deflated 27%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 9%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 20%)
# ...

# %%
# !scp '/content/runs_yolov8bis.zip' '/content/gdrive/My Drive/'
